# %%
import torch

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
date = '2020-03-21'

site = 'SO2/SO2_C_V2'
idx = '31TCJ'

# 5 meter, VENUS
l = torch.load(f"../data/supres/{site}_{idx}_{date}_05m_b2b3b4b8.pt")
l = np.array(l)
np.save(f'../data/supres/numpy-allbands/{idx}_{date}_05m.npy', l)

# 10 meter, Sentinel
s = torch.load(f"../data/supres/{site}_{idx}_{date}_10m_b2b3b4b8.pt")
np.save(f'../data/supres/numpy-allbands/{idx}_{date}_10m.npy', np.array(s))

# 5 meter, VENUS
l = torch.load(f"../data/supres/{site}_{idx}_{date}_05m_b4b5b6b8a.pt")
l = np.array(l)
np.save(f'../data/supres/numpy-allbands/{idx}_{date}_05m-2.npy', l)

# 20 meter, Sentinel
l = torch.load(f"../data/supres/{site}_{idx}_{date}_20m_b4b5b6b8a.pt")
l = np.array(l)
np.save(f'../data/supres/numpy-allbands/{idx}_{date}_20m.npy', l)

# %%
plt.figure(figsize=(20, 16))
sns.heatmap(l[2, 0, ...])

# %%
s = torch.load("../data/supres/SO2/SO2_C_V2_31TCJ_2019-07-15_10m_b2b3b4b8.pt")

np.save('../data/supres/numpy/31TCJ_2019-07-15_10m.npy', np.array(s))

# %%
plt.figure(figsize=(20, 16))
sns.heatmap(s[11, 0], vmax = 2500)
# Out:
# <AxesSubplot:>
