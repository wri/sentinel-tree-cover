# %%
import sklearn
import numpy as np
from tqdm import tqdm_notebook, tnrange

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_x = np.load("../../tile_data/processed/data_x_l2a_processed.npy")
data_y = np.load("../../tile_data/processed/data_y_l2a_processed.npy")
lengths = np.load("../../tile_data/processed/length_l2a_processed.npy")

data_x = np.delete(data_x, 14, -1)

# %%
from scipy.ndimage import median_filter
from skimage.transform import resize
for sample in tnrange(0, len(data_x)):
    filtered = median_filter(data_x[sample, 0, :, :, 10], size = 5)
    filtered = np.reshape(filtered, (8, 2, 8, 2))
    filtered = np.mean(filtered, axis = (1, 3))
    filtered = resize(filtered, (16, 16), 0)
    data_x[sample, :, :, :, 10] = np.stack([filtered] * 24)
    
#data_x = np.delete(data_x, 10, -1)
print(data_x.shape)
# Out:
# HBox(children=(IntProgress(value=0, max=4390), HTML(value='')))
# (4390, 24, 16, 16, 16)

# %%
below_1 = [i for i, val in enumerate(data_x[:, :, :, :, :-2]) if np.min(val) < -1.5]
above_1 = [i for i, val in enumerate(data_x[:, :, :, :, :-2]) if np.max(val) > 1.5]
min_vals = [np.min(val) for i, val in enumerate(data_x[:, :, :, :, :-2]) if np.min(val) < -1.5]
max_vals = [np.max(val) for i, val in enumerate(data_x[:, :, :, :, :-2]) if np.max(val) > 1.5]
nans = [i for i, val in enumerate(data_x) if np.sum(np.isnan(val)) > 0]
oob_vals = [i for i, val in enumerate(data_x) if np.max(val[:, :, :, 0]) > 0.7]
print(oob_vals)

outliers = below_1 + above_1 + nans + oob_vals
outliers = list(set(outliers))
print("The outliers are: {}, totalling {}".format(outliers, len(outliers)))
print("\n")
print(min_vals, max_vals)
data_x = data_x[[x for x in range(0, len(data_x)) if x not in outliers]]
data_y = data_y[[x for x in range(0, len(data_y)) if x not in outliers]]
lengths = lengths[[x for x in range(0, len(lengths)) if x not in outliers]]
# Out:
# [3906, 3913, 3915, 3916, 3921, 3949, 3972, 3984, 3985, 4009, 4016, 4058, 4060, 4092, 4096, 4133, 4179, 4186, 4189, 4191, 4310, 4311, 4312, 4319, 4321, 4333, 4335, 4339, 4343, 4348, 4352, 4357, 4360, 4365, 4366, 4376, 4383]
# The outliers are: [4096, 4352, 3972, 4357, 4360, 4365, 4366, 3984, 3985, 2071, 4376, 4383, 4133, 4009, 4141, 4016, 3906, 3913, 3915, 3916, 3921, 4179, 4310, 4311, 4312, 4058, 4186, 4060, 4189, 4319, 4191, 4321, 3943, 4092, 3949, 4333, 3951, 4335, 4339, 1525, 4343, 4348], totalling 42
#
#
# [-1.5637276, -1.508853, -1.71253, -1.6176922, -1.6507452, -1.7271925] [1.5485176, 1.5207762, 1.5558996, 1.6954132, 1.6817182, 1.5697637, 1.7376012, 1.5934502, 1.6265625, 1.6901331]

# %%
min_all = [0.020395646858960392,
 0.03833778686821461,
 0.022913980782032013,
 0.08838867269456387,
 0.05731564749032259,
 0.0796274145692587,
 0.08639285631477833,
 0.08918419919908048,
 0.07416137464344502,
 0.04398707151412964,
 0.0,
 0.008659180235117674,
 -0.0134716229327023,
 0.006902076792903247,
 0.006362500241957605,
 4.999999873689376e-05]

max_all = [0.18219037026166907,
 0.27367106080055237,
 0.3996005910634992,
 0.4859166720509528,
 0.4492199122905731,
 0.46700127094984045,
 0.49433933556079857,
 0.5116616946458816,
 0.6353135156631469,
 0.5636022371053693,
 0.3590170443058014,
 0.693415229320526,
 0.3948741647601127,
 0.6290205121040344,
 0.8152220940589849,
 0.14367499947547913]



min_all = []
max_all = []

for band in range(0, data_x.shape[-1]):
    mins = np.percentile(data_x[:, :, :, :, band], 1)
    maxs = np.percentile(data_x[:, :, :, :, band], 99)
    #mins, maxs = (np.min(data_x[:, :, :, :, band]), np.max(data_x[:, :, :, :, band]))
    #mins = min_all[band]
    #maxs = max_all[band]
    data_x[:, :, :, :, band] = np.clip(data_x[:, :, :, :, band], mins, maxs)
    midrange = (maxs + mins) / 2
    rng = maxs - mins
    standardized = (data_x[:, :, :, :, band] - midrange) / (rng / 2)
    data_x[:, :, :, :, band] = standardized
    
    min_all.append(mins)
    max_all.append(maxs)
    
print("The data has been scaled to [{}, {}]".format(np.min(data_x), np.max(data_x)))
# Out:
# The data has been scaled to [-1.0000001192092896, 1.000000238418579]

# %%
data_x = np.mean(data_x, axis = 1)
data_x = data_x[:, 1:15, 1:15, :]
data_x = np.reshape(data_x, (data_x.shape[0]*data_x.shape[1]*data_x.shape[2], data_x.shape[-1]))
data_y = np.reshape(data_y, (data_y.shape[0]*14*14))

# %%
test_x = np.load("../../tile_data/processed/test_x_l2a_processed.npy")
test_y = np.load("../../tile_data/processed/test_y_l2a_processed.npy")
test_lengths = np.load("../../tile_data/processed/test_length_l2a_processed.npy")

test_x = np.delete(test_x, 14, -1)
#test_x = np.delete(test_x, 13, -1)


below_1 = [i for i, val in enumerate(test_x[:, :, :, :, :-2]) if np.min(val) < -1.5]
above_1 = [i for i, val in enumerate(test_x[:, :, :, :, :-2]) if np.max(val) > 1.5]
min_vals = [np.min(val) for i, val in enumerate(test_x[:, :, :, :, :-2]) if np.min(val) < -1.5]
max_vals = [np.max(val) for i, val in enumerate(test_x[:, :, :, :, :-2]) if np.max(val) > 1.5]
nans = [i for i, val in enumerate(test_x) if np.sum(np.isnan(val)) > 0]
outliers = below_1 + above_1 + nans
outliers = list(set(outliers))
print("The outliers are: {}, totalling {}".format(outliers, len(outliers)))
print("\n")
print(min_vals, max_vals)

for i in range(len(test_x)):
    mins = np.min(test_x[i, :, :, :, :])
    maxs = np.max(test_x[i, :, :, :, :])
    if mins < -1 or maxs > 1:
        offender_max = np.argmax(np.max(test_x[i, :, :, :, :], (0, 1, 2)), -1)
        offender_min = np.argmin(np.min(test_x[i, :, :, :, :], (0, 1, 2)), -1)
        
        print("{} Offender max/min: {} {}".format(i, offender_max, offender_min))
test_x = test_x[[x for x in range(0, len(test_x)) if x not in outliers]]
test_y = test_y[[x for x in range(0, len(test_y)) if x not in outliers]]
test_lengths = test_lengths[[x for x in range(0, len(test_lengths)) if x not in outliers]]

for sample in tnrange(0, len(test_x)):
    filtered = median_filter(test_x[sample, 0, :, :, 10], size = 5)
    filtered = np.reshape(filtered, (8, 2, 8, 2))
    filtered = np.mean(filtered, axis = (1, 3))
    filtered = resize(filtered, (16, 16), 0)
    test_x[sample, :, :, :, 10] = np.stack([filtered] * 24)

#test_x = np.delete(test_x, 10, -1)
    
for band in range(0, test_x.shape[-1]):
    mins = min_all[band]
    maxs = max_all[band]
    test_x[:, :, :, :, band] = np.clip(test_x[:, :, :, :, band], mins, maxs)
    midrange = (maxs + mins) / 2
    rng = maxs - mins
    standardized = (test_x[:, :, :, :, band] - midrange) / (rng / 2)
    test_x[:, :, :, :, band] = standardized
    
    
print("The data has been scaled to [{}, {}]".format(np.min(test_x), np.max(test_x)))
print(test_x.shape)
# Out:
# The outliers are: [805, 682, 714, 750, 593, 723, 789, 794, 764, 890], totalling 10
#
#
# [-1.7179548, -1.5627671, -1.8532804, -1.7344598, -1.566039, -1.5506328, -1.5647379, -1.5482582, -1.5288317] [1.6422757, 1.6066049, 1.7172077, 1.5512294, 1.5134994]
# 0 Offender max/min: 14 12
# 2 Offender max/min: 14 10
# 7 Offender max/min: 14 15
# 9 Offender max/min: 14 10
# 12 Offender max/min: 14 12
# 17 Offender max/min: 14 10
# 18 Offender max/min: 14 10
# 19 Offender max/min: 14 12
# 21 Offender max/min: 14 12
# 25 Offender max/min: 14 10
# 33 Offender max/min: 14 10
# 41 Offender max/min: 14 10
# 52 Offender max/min: 14 10
# 53 Offender max/min: 14 12
# 54 Offender max/min: 14 12
# 55 Offender max/min: 14 12
# 58 Offender max/min: 14 12
# 61 Offender max/min: 14 12
# 63 Offender max/min: 14 12
# 68 Offender max/min: 14 12
# 69 Offender max/min: 14 12
# 70 Offender max/min: 14 12
# 73 Offender max/min: 14 10
# 77 Offender max/min: 14 12
# 78 Offender max/min: 14 10
# 79 Offender max/min: 14 10
# 81 Offender max/min: 14 12
# 97 Offender max/min: 14 12
# 99 Offender max/min: 14 12
# 100 Offender max/min: 14 10
# 101 Offender max/min: 14 12
# 104 Offender max/min: 14 10
# 105 Offender max/min: 14 12
# 106 Offender max/min: 14 12
# 108 Offender max/min: 14 10
# 109 Offender max/min: 14 12
# 110 Offender max/min: 14 12
# 111 Offender max/min: 14 10
# 115 Offender max/min: 14 12
# 118 Offender max/min: 14 10
# 120 Offender max/min: 14 10
# 128 Offender max/min: 14 10
# 131 Offender max/min: 14 12
# 141 Offender max/min: 14 10
# 148 Offender max/min: 14 12
# 153 Offender max/min: 14 12
# 159 Offender max/min: 14 12
# 180 Offender max/min: 14 12
# 205 Offender max/min: 14 10
# 212 Offender max/min: 14 12
# 223 Offender max/min: 14 10
# 226 Offender max/min: 14 10
# 236 Offender max/min: 14 10
# 239 Offender max/min: 14 12
# 244 Offender max/min: 14 10
# 249 Offender max/min: 14 10
# 253 Offender max/min: 14 10
# 272 Offender max/min: 14 10
# 277 Offender max/min: 14 10
# 281 Offender max/min: 14 10
# 282 Offender max/min: 14 10
# 284 Offender max/min: 14 10
# 285 Offender max/min: 14 12
# 288 Offender max/min: 14 12
# 302 Offender max/min: 14 10
# 306 Offender max/min: 14 10
# 319 Offender max/min: 14 8
# 320 Offender max/min: 14 10
# 323 Offender max/min: 14 15
# 324 Offender max/min: 14 10
# 329 Offender max/min: 14 10
# 330 Offender max/min: 14 11
# 332 Offender max/min: 14 10
# 333 Offender max/min: 14 12
# 334 Offender max/min: 14 10
# 335 Offender max/min: 14 10
# 340 Offender max/min: 14 10
# 341 Offender max/min: 14 12
# 345 Offender max/min: 14 10
# 346 Offender max/min: 14 12
# 349 Offender max/min: 14 10
# 358 Offender max/min: 14 12
# 359 Offender max/min: 14 11
# 360 Offender max/min: 14 12
# 364 Offender max/min: 14 10
# 366 Offender max/min: 14 12
# 367 Offender max/min: 14 12
# 368 Offender max/min: 14 11
# 370 Offender max/min: 14 12
# 375 Offender max/min: 14 12
# 380 Offender max/min: 14 12
# 382 Offender max/min: 14 12
# 384 Offender max/min: 14 12
# 386 Offender max/min: 14 12
# 389 Offender max/min: 14 10
# 390 Offender max/min: 14 12
# 394 Offender max/min: 14 12
# 407 Offender max/min: 14 12
# 418 Offender max/min: 14 10
# 428 Offender max/min: 14 10
# 443 Offender max/min: 14 10
# 447 Offender max/min: 14 10
# 450 Offender max/min: 14 10
# 452 Offender max/min: 14 10
# 461 Offender max/min: 14 10
# 464 Offender max/min: 14 10
# 470 Offender max/min: 14 10
# 473 Offender max/min: 9 12
# 474 Offender max/min: 14 12
# 485 Offender max/min: 14 12
# 496 Offender max/min: 14 9
# 497 Offender max/min: 14 12
# 502 Offender max/min: 14 10
# 504 Offender max/min: 14 12
# 505 Offender max/min: 14 12
# 508 Offender max/min: 14 12
# 509 Offender max/min: 14 12
# 510 Offender max/min: 14 12
# 511 Offender max/min: 14 12
# 513 Offender max/min: 14 12
# 514 Offender max/min: 14 12
# 516 Offender max/min: 14 12
# 520 Offender max/min: 14 12
# 521 Offender max/min: 14 15
# 523 Offender max/min: 14 10
# 529 Offender max/min: 14 12
# 530 Offender max/min: 14 12
# 531 Offender max/min: 14 10
# 532 Offender max/min: 14 12
# 534 Offender max/min: 14 12
# 538 Offender max/min: 14 10
# 541 Offender max/min: 14 15
# 542 Offender max/min: 14 10
# 545 Offender max/min: 14 12
# 547 Offender max/min: 6 11
# 553 Offender max/min: 14 15
# 555 Offender max/min: 14 12
# 571 Offender max/min: 11 11
# 576 Offender max/min: 14 10
# 582 Offender max/min: 14 12
# 584 Offender max/min: 14 10
# 593 Offender max/min: 4 11
# 598 Offender max/min: 14 0
# 608 Offender max/min: 14 0
# 609 Offender max/min: 14 12
# 615 Offender max/min: 14 11
# 620 Offender max/min: 14 15
# 623 Offender max/min: 11 12
# 627 Offender max/min: 14 12
# 632 Offender max/min: 14 10
# 635 Offender max/min: 11 11
# 637 Offender max/min: 14 12
# 639 Offender max/min: 14 12
# 641 Offender max/min: 14 10
# 642 Offender max/min: 14 12
# 646 Offender max/min: 14 11
# 647 Offender max/min: 14 12
# 651 Offender max/min: 11 11
# 652 Offender max/min: 14 0
# 657 Offender max/min: 14 10
# 659 Offender max/min: 14 12
# 661 Offender max/min: 14 12
# 664 Offender max/min: 14 12
# 666 Offender max/min: 14 12
# 667 Offender max/min: 14 0
# 670 Offender max/min: 14 12
# 672 Offender max/min: 14 12
# 678 Offender max/min: 14 15
# 679 Offender max/min: 14 10
# 680 Offender max/min: 14 12
# 682 Offender max/min: 14 11
# 684 Offender max/min: 14 10
# 685 Offender max/min: 11 11
# 689 Offender max/min: 14 12
# 698 Offender max/min: 14 12
# 699 Offender max/min: 14 15
# 700 Offender max/min: 14 10
# 705 Offender max/min: 14 12
# 710 Offender max/min: 14 12
# 714 Offender max/min: 11 11
# 715 Offender max/min: 14 12
# 723 Offender max/min: 11 11
# 724 Offender max/min: 14 12
# 726 Offender max/min: 14 12
# 729 Offender max/min: 12 12
# 733 Offender max/min: 14 12
# 735 Offender max/min: 14 12
# 742 Offender max/min: 5 11
# 744 Offender max/min: 14 7
# 745 Offender max/min: 14 12
# 750 Offender max/min: 11 11
# 753 Offender max/min: 14 15
# 762 Offender max/min: 14 12
# 764 Offender max/min: 4 11
# 770 Offender max/min: 14 12
# 771 Offender max/min: 3 11
# 777 Offender max/min: 14 12
# 784 Offender max/min: 14 12
# 786 Offender max/min: 14 11
# 787 Offender max/min: 14 12
# 789 Offender max/min: 4 11
# 791 Offender max/min: 4 11
# 792 Offender max/min: 14 12
# 793 Offender max/min: 14 11
# 794 Offender max/min: 11 11
# 795 Offender max/min: 14 15
# 798 Offender max/min: 14 12
# 800 Offender max/min: 14 10
# 805 Offender max/min: 4 11
# 812 Offender max/min: 14 12
# 813 Offender max/min: 14 12
# 816 Offender max/min: 14 12
# 817 Offender max/min: 14 12
# 819 Offender max/min: 4 11
# 821 Offender max/min: 4 11
# 823 Offender max/min: 4 11
# 830 Offender max/min: 14 11
# 831 Offender max/min: 14 11
# 832 Offender max/min: 14 11
# 838 Offender max/min: 14 11
# 840 Offender max/min: 14 15
# 841 Offender max/min: 11 11
# 842 Offender max/min: 11 11
# 843 Offender max/min: 14 10
# 845 Offender max/min: 14 12
# 846 Offender max/min: 6 11
# 849 Offender max/min: 11 11
# 855 Offender max/min: 14 11
# 858 Offender max/min: 14 12
# 859 Offender max/min: 14 10
# 864 Offender max/min: 14 11
# 868 Offender max/min: 14 12
# 869 Offender max/min: 14 11
# 870 Offender max/min: 14 11
# 874 Offender max/min: 11 11
# 876 Offender max/min: 14 12
# 878 Offender max/min: 14 13
# 879 Offender max/min: 14 6
# 883 Offender max/min: 14 12
# 884 Offender max/min: 4 11
# 885 Offender max/min: 11 11
# 888 Offender max/min: 11 11
# 889 Offender max/min: 4 11
# 890 Offender max/min: 4 11
# 897 Offender max/min: 14 11
# 899 Offender max/min: 4 11
# 902 Offender max/min: 14 10
# 905 Offender max/min: 14 12
# 906 Offender max/min: 14 12
# 908 Offender max/min: 14 5
# 912 Offender max/min: 14 11
# 914 Offender max/min: 11 11
# 916 Offender max/min: 14 10
# 927 Offender max/min: 9 12
# 930 Offender max/min: 14 12
# 936 Offender max/min: 14 10
# 941 Offender max/min: 14 12
# 946 Offender max/min: 14 12
# 948 Offender max/min: 14 10
# 953 Offender max/min: 14 5
# 966 Offender max/min: 14 12
# 967 Offender max/min: 11 12
# 971 Offender max/min: 14 12
# 973 Offender max/min: 14 12
# 975 Offender max/min: 14 12
# 977 Offender max/min: 14 12
# 978 Offender max/min: 14 12
# 979 Offender max/min: 14 12
# 980 Offender max/min: 14 11
# 981 Offender max/min: 14 12
# HBox(children=(IntProgress(value=0, max=972), HTML(value='')))
# The data has been scaled to [-1.0000001192092896, 1.000000238418579]
# (972, 24, 16, 16, 16)

# %%
test_x = np.mean(test_x, axis = 1)
test_x = test_x[:, 1:15, 1:15, :]
test_x = np.reshape(test_x, (test_x.shape[0]*test_x.shape[1]*test_x.shape[2], test_x.shape[-1]))
test_y = np.reshape(test_y, (test_y.shape[0]*14*14))

# %%
countries = {'africaeast-test': [0, 34],
 'africawest-test': [35, 96],
 'cameroon-test': [97, 135],
 'ethiopia-test': [136, 248],
 'ghana-test': [249, 282],
 'ghana-test-large': [283, 318],
 'global-test': [319, 417],
 'india-test': [418, 468],
 'kenya-test': [469, 557],
 'lac-north-test': [558, 598],
 'lac-south-test': [599, 640]}

# %%
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor(n_estimators=100, random_state=0)
clf.fit(data_x, data_y)
y_pred = clf.predict(test_x)

# %%
y_pred = clf.predict(test_x)
y_pred[np.where(y_pred >= 0.43)] = 1.
y_pred[np.where(y_pred < 0.43)] = 0.

# %%
print(sklearn.metrics.classification_report(test_y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89    120673
#          1.0       0.83      0.78      0.80     69839
#
#     accuracy                           0.86    190512
#    macro avg       0.85      0.84      0.85    190512
# weighted avg       0.86      0.86      0.86    190512

# %%
path = "../../tile_data/honduras_large/processed/"

def standardize_tile(arr):
    for x in range(0, arr.shape[-1]):
        mins = min_all[x]
        maxs = max_all[x]
        arr[:, :, :, x] = np.clip(arr[:, :, :, x], mins, maxs)
        midrange = (maxs + mins) / 2
        rng = maxs - mins
        standardized = (arr[:, :, :, x] - midrange) / (rng / 2)
        arr[:, :, :, x] = standardized
        mins, maxs = (np.min(arr[:, :, :, x]), np.max(arr[:, :, :, x]))
    return arr

def predict_tile(y, x, path = path):
    tile_x = np.load(path + str(y) + "/" + str(x) + ".npy")
    tile_x = np.delete(tile_x, 14, -1)
    tile_x = standardize_tile(tile_x)
    tile_x = np.mean(tile_x, axis = 0)
    tile_x[np.isnan(tile_x)] = 0.
    tile_x = tile_x[1:-1, 1:-1, :]
     
    tile_x = np.reshape(tile_x, (tile_x.shape[0]*tile_x.shape[1], tile_x.shape[-1]))
    tile_y = clf.predict(tile_x)
    tile_y = np.reshape(tile_y, (126, 126))
    return tile_y

tile_y = predict_tile(0, 1)

# %%
all_preds = []
for row in tnrange(5, 10):
    pred_i = [predict_tile(row, col) for col in range(10, 20)]
    pred_i = np.concatenate(pred_i, axis = 1)
    all_preds.append(pred_i)
all_preds.reverse()
stacked = np.concatenate(all_preds, axis = 0)
#stacked = stacked[400:600, 400:500]
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))

# %%
plt.figure(figsize=(20, 17))
stacked[np.where(stacked >= 0.6)] = 1.
stacked[np.where(stacked < 0.6)] = 0.
sns.heatmap(stacked)

# %%
plt.figure(figsize=(9, 15))
# HONDURAS IS 200:400, 540:640
sns.heatmap(stacked[200:400, 1800-1260:1900-1260])

# %%
plt.figure(figsize=(20, 17))
stacked[np.where(stacked >= 0.4)] = 1.
stacked[np.where(stacked < 0.4)] = 0.
sns.heatmap(stacked)

# %%
# GHANA is 250:450, 350:450
stacked = stacked[250:450, 350:450]
plt.figure(figsize=(10, 15))
sns.heatmap(stacked)

# %% [markdown]
# # Metrics

# %%
from sklearn.metrics import f1_score
def compute_f1_score_at_tolerance(true, pred, tolerance = 1):
    fp = 0
    tp = 0
    fn = 0
    true = true.reshape((14, 14))
    pred = pred.reshape((14, 14))
    
    tp = np.zeros_like(true)
    fp = np.zeros_like(true)
    fn = np.zeros_like(true)
    
    
    
    for x in range(true.shape[0]):
        for y in range(true.shape[1]):
            min_x = np.max([0, x-1])
            min_y = np.max([0, y-1])
            max_y = np.min([true.shape[0], y+2])
            max_x = np.min([true.shape[0], x+2])
            if true[x, y] == 1:
                if np.sum(pred[min_x:max_x, min_y:max_y]) > 0:
                    if pred[x, y] == 1:
                        tp[x, y] = 1
                else:
                    fn[x, y] = 1
            if pred[x, y] == 1:
                if np.sum(true[min_x:max_x, min_y:max_y]) > 0:
                    if true[x, y] == 1:
                        tp[x, y] = 1
                else:
                    fp[x, y] = 1
    precision =  np.sum(tp) / (np.sum(tp) + np.sum(fp))
    recall = np.sum(tp) / (np.sum(tp) + np.sum(fn))
    f1 = 2 * ((precision * recall) / (precision + recall))

    return f1


true_canopy = []
error_canopy = []
pred_canopy = []
f1_hard = []
f1_soft = []

for i in range(0, y_pred.shape[0], 196):
    true = test_y[i:i+196]
    pred = y_pred[i:i +196]
    true_canopy.append(np.sum(true) / 1.96)
    error_canopy.append(abs(np.sum(pred) - np.sum(true)) / 1.96)
    pred_canopy.append(np.sum(pred) / 1.96)
    f1_hard.append(f1_score(true, pred))
    f1_soft.append(compute_f1_score_at_tolerance(np.array(true),
                                                 np.array(pred)))
# Out:
# /Users/john.brandt/anaconda3/envs/remote_sensing/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/john.brandt/anaconda3/envs/remote_sensing/lib/python3.6/site-packages/sklearn/metrics/classification.py:1439: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# /Users/john.brandt/.local/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in double_scalars
# /Users/john.brandt/.local/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in double_scalars
# /Users/john.brandt/.local/lib/python3.6/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in double_scalars

# %%
import pandas as pd
import math
metrics = pd.DataFrame({'true': true_canopy,
                        'pred': pred_canopy,
                        'f1_hard': f1_hard,
                        'f1_soft': f1_soft,
                        'error': error_canopy})

res = map(lambda x: int(math.floor(x / 20.0)) * 20, true_canopy)
res = [x for x in res]
metrics['group'] = res

# %%
sns.pointplot('group', 'f1_hard',
    data=metrics, dodge=True, join=False)

# %%
sns.pointplot('group', 'f1_soft',
    data=metrics, dodge=True, join=False)

# %%
sns.pointplot('group', 'error',
    data=metrics, dodge=True, join=False)

# %%
metrics['model'] = 'random_forest'
metrics.to_csv("../../data/metrics/random_forest.csv")
