# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
idx = '135804079'

# %%
old_s2 = np.load("../../data/old-s2/"+ idx +".npy")
old_s1 = np.load("../../data/old-s1/"+ idx +".npy")

# %%
sns.scatterplot(y = np.mean(old_s1, axis = (1, 2, 3)), x = [x for x in range(24)])

# %%
sns.scatterplot(y = np.mean(new_s1[:, :, :, 0], axis = (1, 2)), x = [x for x in range(24)])

# %%
sns.heatmap(old_s1[-4, :, :, 0])

# %%
new_s2 = np.load("../../data/test-s2/"+ idx +".npy")
new_s1 = np.load("../../data/test-s1/"+ idx +".npy")

# %%
sns.heatmap(new_s1[-4, :, :, 0])

# %%
np.sum(abs(old_s2 - new_s2), axis = (0, 1, 2))
# Out:
# array([4.61080750e+00, 3.37943925e+00, 2.58982651e+00, 2.53129532e+00,
#        1.99955131e+00, 1.87328398e+00, 2.19142716e+00, 2.30906980e+00,
#        1.66557986e+00, 1.56792321e+00, 7.04328218e-06, 4.67832728e+00,
#        2.54932659e+00, 5.17735934e+00, 3.45915057e+00])

# %%
np.sum(abs(old_s1 - new_s1), axis = (1, 2, 3))
# Out:
# array([11.70160585, 11.42617245, 12.19697934, 11.59124382, 10.07617247,
#         3.16250351,  8.31317522,  8.31317522, 11.62225963,  3.2329426 ,
#         2.96752623, 10.32833314, 12.1173549 , 15.29560507, 22.33395186,
#         6.14652267, 24.12300178,  6.15860996,  7.00328719, 33.99984612,
#        35.56245618,  7.01152213, 22.35509399, 21.05758792])
