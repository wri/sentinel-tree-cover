# %%
import numpy as np
import seaborn as sns

x = np.load("../../project-monitoring/tiles/2017//5467/1086/smooth.npy")

# %%
x= np.load("../../src/mosaic.npy")
sns.heatmap(x[..., 0], vmax = 0.1)
# Out:
# <AxesSubplot:>

# %%
#x= np.load("../../src/mosaic.npy")
sns.heatmap(x[10, ..., 0], vmax = 20000)
# Out:
# <AxesSubplot:>
