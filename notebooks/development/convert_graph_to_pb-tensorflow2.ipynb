# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.logging.set_verbosity(tf.logging.ERROR)
import math
import re
# Out:
# WARNING:tensorflow:From /Users/work/mambaforge/envs/tf2.9/lib/python3.10/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
sess = tf.Session()
from keras import backend as K

from time import sleep

import keras
from tensorflow.python.keras.layers import *
from tensorflow.python.keras.layers import ELU
from keras.losses import binary_crossentropy
from tensorflow.python.ops import array_ops
from tensorflow.python.keras.layers import Conv2D, Lambda, Dense, Multiply, Add
from tensorflow.compat.v1.initializers import glorot_normal, lecun_normal
from scipy.ndimage import median_filter
from skimage.transform import resize

import pandas as pd
import numpy as np
from random import shuffle
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import random
import itertools
from keras.regularizers import l1
from tensorflow.python.util import deprecation as deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False
# Out:
# Metal device set to: Apple M3 Max
# 2024-01-09 13:47:24.287337: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-01-09 13:47:24.287478: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# %run ../../src/layers/zoneout.py
# %run ../../src/layers/adabound.py
# %run ../../src/layers/adabelief.py

# %run ../../src/layers/convgru.py
# %run ../../src/layers/dropblock.py
# %run ../../src/layers/extra_layers.py

# %%
def cse_block(prevlayer, prefix):
    '''Channel excitation and spatial squeeze layer. 
       Calculates the mean of the spatial dimensions and then learns
       two dense layers, one with relu, and one with sigmoid, to rerank the
       input channels
       
         Parameters:
          prevlayer (tf.Variable): input layer
          prefix (str): prefix for tensorflow scope

         Returns:
          x (tf.Variable): output of the cse_block
    '''
    mean = Lambda(lambda xin: K.mean(xin, axis=[1, 2]))(prevlayer)
    lin1 = Dense(K.int_shape(prevlayer)[3] // 2, name=prefix + 'cse_lin1', activation='relu')(mean)
    lin2 = Dense(K.int_shape(prevlayer)[3], name=prefix + 'cse_lin2', activation='sigmoid')(lin1)
    x = Multiply()([prevlayer, lin2])
    return x


def sse_block(prevlayer, prefix):
    '''Spatial excitation and channel squeeze layer.
       Calculates a 1x1 convolution with sigmoid activation to create a 
       spatial map that is multiplied by the input layer

         Parameters:
          prevlayer (tf.Variable): input layer
          prefix (str): prefix for tensorflow scope

         Returns:
          x (tf.Variable): output of the sse_block
    '''
    conv = Conv2D(1, (1, 1), padding="same", kernel_initializer=tf.keras.initializers.he_normal(),
                  activation='sigmoid', strides=(1, 1),
                  name=prefix + "_conv")(prevlayer)
    conv = Multiply(name=prefix + "_mul")([prevlayer, conv])
    return conv


def csse_block(x, prefix):
    '''Implementation of Concurrent Spatial and Channel 
       ‘Squeeze & Excitation’ in Fully Convolutional Networks
    
        Parameters:
          prevlayer (tf.Variable): input layer
          prefix (str): prefix for tensorflow scope

         Returns:
          x (tf.Variable): added output of cse and sse block
          
         References:
          https://arxiv.org/abs/1803.02579
    '''
    #cse = cse_block(x, prefix)
    sse = sse_block(x, prefix)
    #x = Add(name=prefix + "_csse_mul")([cse, sse])

    return sse

class ReflectionPadding2D(Layer):
    def __init__(self, padding=(1, 1), **kwargs):
        self.padding = tuple(padding)
        self.input_spec = [InputSpec(ndim=4)]
        super(ReflectionPadding2D, self).__init__(**kwargs)

    def compute_output_shape(self, s):
        """ If you are using "channels_last" configuration"""
        return (s[0], s[1] + 2 * self.padding[0], s[2] + 2 * self.padding[1], s[3])

    def call(self, x, mask=None):
        w_pad,h_pad = self.padding
        print("ZERO PADDING")
        return tf.pad(x, [[0,0], [h_pad,h_pad], [w_pad,w_pad], [0,0] ], 'REFLECT')
    
class ReflectionPadding5D(Layer):
    def __init__(self, padding=(1, 1), **kwargs):
        self.padding = tuple(padding)
        self.input_spec = [InputSpec(ndim=4)]
        super(ReflectionPadding5D, self).__init__(**kwargs)

    def compute_output_shape(self, s):
        """ If you are using "channels_last" configuration"""
        return (s[0], s[1] + 2 * self.padding[0], s[2] + 2 * self.padding[1], s[3])

    def call(self, x, mask=None):
        w_pad,h_pad = self.padding
        print("ZERO PADDING")
        return tf.pad(x, [[0,0], [0, 0], [h_pad,h_pad], [w_pad,w_pad], [0,0] ], 'REFLECT')

# %%
kernel = np.array([[[[[1,-1], [-1, 1]]]]])
kernel.shape
# Out:
# (1, 1, 1, 2, 2)

# %%
def gru_block(inp, length, size, flt, scope, train, normalize = True):
    '''Bidirectional convolutional GRU block with 
       zoneout and CSSE blocks in each time step

         Parameters:
          inp (tf.Variable): (B, T, H, W, C) layer
          length (tf.Variable): (B, T) layer denoting number of
                                steps per sample
          size (int): kernel size of convolution
          flt (int): number of convolution filters
          scope (str): tensorflow variable scope
          train (tf.Bool): flag to differentiate between train/test ops
          normalize (bool): whether to compute layer normalization

         Returns:
          gru (tf.Variable): (B, H, W, flt*2) bi-gru output
          steps (tf.Variable): (B, T, H, W, flt*2) output of each step
    '''
    with tf.variable_scope(scope):
        print(f"GRU input shape {inp.shape}, zoneout: {0.1}")
        """
        cell_fw = ConvLSTMCell(shape = size, filters = flt,
                               kernel = [3, 3], forget_bias=1.0, 
                               activation=tf.tanh, normalize=True, 
                               peephole=False, data_format='channels_last', reuse=None)
        cell_bw = ConvLSTMCell(shape = size, filters = flt,
                               kernel = [3, 3], forget_bias=1.0, 
                               activation=tf.tanh, normalize=True, 
                               peephole=False, data_format='channels_last', reuse=None)
        """
        cell_fw = ConvGRUCell(shape = size, filters = flt,
                           kernel = [3, 3], padding = 'VALID', normalize = normalize, sse = True)
        cell_bw = ConvGRUCell(shape = size, filters = flt,
                           kernel = [3, 3], padding = 'VALID', normalize = normalize, sse = True)
        zoneout = 0.75
        cell_fw = ZoneoutWrapper(
           cell_fw, zoneout_drop_prob = zoneout, is_training = train)
        cell_bw = ZoneoutWrapper(
            cell_bw, zoneout_drop_prob = zoneout, is_training = train)
        print(inp.shape)
        steps, out = convGRU(inp, cell_fw, cell_bw, length)
        print(f"Zoneout: {zoneout}")
        gru = tf.concat(out, axis = -1)
        steps = tf.concat(steps, axis = -1)
        print(f"Down block output shape {gru.shape}")
    return gru, steps


def attention(inp, units):
    weighted = TimeDistributed(Conv2D(units, (1, 1), padding = 'same', kernel_initializer = tf.keras.initializers.Ones(),
                            activation = 'sigmoid', strides = (1, 1), use_bias = False, ))(inp) 
    alphas = tf.reduce_sum(weighted, axis = 1, keep_dims = True)
    alphas = weighted / alphas
    multiplied = tf.reduce_sum(alphas * inp, axis = 1)
    print(multiplied.shape)
    return multiplied

# %%
class WSConv2D(tf.keras.layers.Conv2D):
    def __init__(self, *args, **kwargs):
        super(WSConv2D, self).__init__(kernel_initializer="he_normal", *args, **kwargs)

    def standardize_weight(self, weight, eps):

        mean = tf.math.reduce_mean(weight, axis=(0, 1, 2), keepdims=True)
        weight = weight - mean
        var = tf.keras.backend.std(weight, axis=[0, 1, 2], keepdims=True)
        weight = weight / (var + 1e-5)
        return weight

    def call(self, inputs, eps=1e-4):
        self.kernel.assign(self.kernel, eps)
        return super().call(inputs)

def partial_conv(x, channels, kernel=3, stride=1, norm = True, use_bias=False, padding='SAME', scope='conv_0'):
    

    
    with tf.variable_scope(scope):
        if padding.lower() == 'SAME'.lower() :
            with tf.variable_scope('mask'):
                _, h, w, _ = x.get_shape().as_list()

                slide_window = kernel * kernel
                mask = tf.ones(shape=[1, h, w, 1])

                update_mask = tf.layers.conv2d(mask, filters=1,
                                               kernel_size=kernel, kernel_initializer=tf.constant_initializer(1.0),
                                               strides=stride, padding=padding, use_bias=False, trainable=False)

                mask_ratio = slide_window / (update_mask + 1e-8)
                update_mask = tf.clip_by_value(update_mask, 0.0, 1.0)
                mask_ratio = mask_ratio * update_mask

            with tf.variable_scope('x'):
                if 4 > 3:
                    x = WSConv2D(filters=channels, kernel_regularizer = None,
                                     kernel_size=kernel,
                                     strides=stride, padding=padding, use_bias=False)(x)
                else:
                    x = tf.layers.conv2d(x, filters=channels, kernel_regularizer = None,
                                     kernel_size=kernel, kernel_initializer=tf.keras.initializers.he_normal(),
                                     strides=stride, padding=padding, use_bias=False)
    
                x = x * mask_ratio
                
                

                if use_bias:
                    bias = tf.get_variable("bias", [channels], initializer=tf.constant_initializer(0.0))

                    x = tf.nn.bias_add(x, bias)
                    x = x * update_mask

        else :
            if 4 > 3:
                x = WSConv2D(filters=channels,kernel_regularizer = None,
                                 kernel_size=kernel,
                                 strides=stride, padding=padding, use_bias=False)(x)
            else:
                x = tf.layers.conv2d(x, filters=channels,kernel_regularizer = None,
                                 kernel_size=kernel, kernel_initializer=tf.keras.initializers.he_normal(),
                                 strides=stride, padding=padding, use_bias=use_bias)

        return x
    

def conv_swish_gn(inp, 
                 is_training, 
                 kernel_size,
                 scope,
                 filters, 
                 keep_rate,
                 stride = (1, 1),
                 activation = True,
                 use_bias = False,
                 norm = True,
                 dropblock = True,
                 csse = True,
                 weight_decay = None,
                 block_size = 5,
                 padding = "SAME",
                 window_size = 48):
    '''2D convolution, batch renorm, relu block, 3x3 drop block. 
       Use_bias must be set to False for batch normalization to work. 
       He normal initialization is used with batch normalization.
       RELU is better applied after the batch norm.
       DropBlock performs best when applied last, according to original paper.

         Parameters:
          inp (tf.Variable): input layer
          is_training (str): flag to differentiate between train/test ops
          kernel_size (int): size of convolution
          scope (str): tensorflow variable scope
          filters (int): number of filters for convolution
          clipping_params (dict): specifies clipping of 
                                  rmax, dmax, rmin for renormalization
          activation (bool): whether to apply RELU
          use_bias (str): whether to use bias. Should always be false

         Returns:
          bn (tf.Variable): output of Conv2D -> Batch Norm -> RELU
        
         References:
          http://papers.nips.cc/paper/8271-dropblock-a-regularization-
              method-for-convolutional-networks.pdf
          https://arxiv.org/abs/1702.03275
          
    '''
    
    bn_flag = "Group Norm" if norm else ""
    activation_flag = "RELU" if activation else "Linear"
    csse_flag = "CSSE" if csse else "No CSSE"
    bias_flag = "Bias" if use_bias else "NoBias"
    drop_flag = "DropBlock" if dropblock else "NoDrop"
        
    
    print("{} {} Conv 2D {} {} {} {} {}".format(scope, kernel_size,
                                                   bn_flag, activation_flag,
                                                   csse_flag, bias_flag, drop_flag))
    
    with tf.variable_scope(scope + "_conv"):
        #conv = Conv2D(filters = filters, kernel_size = (kernel_size, kernel_size),  strides = stride,
        #              activation = None, padding = 'valid', use_bias = use_bias,
                      #kernel_regularizer = weight_decay,
        #              kernel_initializer = tf.keras.initializers.he_normal())(inp)
        conv = partial_conv(inp, filters, kernel=kernel_size, stride=1, 
                            use_bias=False, padding=padding, scope = scope)
    print(f"The non normalized feats are {conv}")    
    if activation:
        conv = tf.nn.swish(conv)
    print(f"The non normalized feats are {conv}")
    # if dropblock:
    #.    mask = make_mask()
    
    if norm:
        conv = group_norm(x = conv, scope = scope, G = 8,#(filters // 4), 
                          window_size = window_size) #mask = mask
    if csse:
        conv = csse_block(conv, "csse_" + scope)
    
    if dropblock: 
        with tf.variable_scope(scope + "_drop"):
            drop_block = DropBlock2D(keep_prob=keep_rate, block_size= block_size)
            conv = drop_block(conv, is_training)
    return conv

# %%
INPUT_SIZE = 172#220 
SIZE_X = 172 # 684

n_bands = 17   
inp = tf.placeholder(tf.float32, shape=(1, 5, INPUT_SIZE, SIZE_X, n_bands))
length = tf.placeholder_with_default(np.full((1,), 4), shape = (None,))
labels = tf.placeholder(tf.float32, shape=(None, INPUT_SIZE - 14, INPUT_SIZE - 14))#, 1))
keep_rate = tf.placeholder_with_default(1.0, ()) # For DropBlock
is_training = tf.placeholder_with_default(False, (), 'is_training') # For BN, DropBlock
alpha = tf.placeholder(tf.float32, shape = ()) # For loss scheduling
ft_lr = tf.placeholder_with_default(0.001, shape = ()) # For loss scheduling
loss_weight = tf.placeholder_with_default(1.0, shape = ())
beta_ = tf.placeholder_with_default(0.0, shape = ())

# %%
# master modmel is 32, 64, 96, 230k paramms
initial_flt = 64
mid_flt = initial_flt * 2
high_flt = initial_flt * 2 * 2
#INPUT_SIZE = 28
#SIZE_X = 28

#inp = ReflectionPadding5D((1, 1))(inp)
gru_input = inp[:, :-1, ...]
#gru_input = tf.concat([inp[:, :-1, ..., :10], inp[:, :-1, ..., 11:]], -1)
gru, steps = gru_block(inp = gru_input, length = length,
                            size = [INPUT_SIZE, SIZE_X, ], # + 2 here for refleclt pad
                            flt = initial_flt // 2,
                            scope = 'down_16',
                            train = is_training)
with tf.variable_scope("gru_drop"):
    drop_block = DropBlock2D(keep_prob=keep_rate, block_size=4)
    gru = drop_block(gru, is_training)
    
# Median conv

median_input = inp[:, -1, ...]
median_conv = conv_swish_gn(inp = median_input, is_training = is_training, stride = (1, 1),
            kernel_size = 3, scope = 'conv_median', filters = initial_flt, 
            keep_rate = keep_rate, activation = True, use_bias = False, norm = True,
            csse = True, dropblock = True, weight_decay = None,
                            window_size = 104)
print(f"Median conv: {median_conv.shape}")

concat1 = tf.concat([gru, median_conv], axis = -1)


concat = conv_swish_gn(inp = concat1, is_training = is_training, stride = (1, 1),
            kernel_size = 3, scope = 'conv_concat', filters = initial_flt,
            keep_rate = keep_rate, activation = True, use_bias = False, norm = True,
            csse = True, dropblock = True, weight_decay = None, padding = "SAME",
                       window_size = 104)
print(f"Concat: {concat.shape}")

    
# MaxPool-conv-swish-GroupNorm-csse
pool1 = MaxPool2D()(concat)
conv1 = conv_swish_gn(inp = pool1, is_training = is_training, stride = (1, 1),
            kernel_size = 3, scope = 'conv1', filters = mid_flt,
            keep_rate = keep_rate, activation = True, use_bias = False, norm = True, padding = "VALID",
            csse = True, dropblock = True, weight_decay = None)
print(f"Conv1: {conv1.shape}")

# MaxPool-conv-swish-csse-DropBlock
pool2 = MaxPool2D()(conv1)
conv2 = conv_swish_gn(inp = pool2, is_training = is_training, stride = (1, 1),
            kernel_size = 3, scope = 'conv2', filters = high_flt, 
            keep_rate = keep_rate, activation = True, use_bias = False, norm = True,
            csse = True, dropblock = True, weight_decay = None, block_size = 4, padding = "VALID",
                     window_size = 24)
print("Encoded", conv2.shape)

# Decoder 4 - 8, upsample-conv-swish-csse-concat-conv-swish
up2 = tf.keras.layers.UpSampling2D((2, 2), interpolation = 'nearest')(conv2)
#up2 = ReflectionPadding2D((1, 1,))(up2)
up2 = conv_swish_gn(inp = up2, is_training = is_training, stride = (1, 1),
                    kernel_size = 3, scope = 'up2', filters = mid_flt, 
                    keep_rate = keep_rate, activation = True,use_bias = False, norm = True,
                    csse = True, dropblock = True, weight_decay = None)
conv1_crop = Cropping2D(2)(conv1)
print(conv1_crop.shape)
up2 = tf.concat([up2, conv1_crop], -1)
#up2 = ReflectionPadding2D((1, 1,))(up2)
up2 = conv_swish_gn(inp = up2, is_training = is_training, stride = (1, 1),
                    kernel_size = 3, scope = 'up2_out', filters = mid_flt, 
                    keep_rate =  keep_rate, activation = True,use_bias = False, norm = True,
                    csse = True, dropblock = True, weight_decay = None)

# Decoder 8 - 14 upsample-conv-swish-csse-concat-conv-swish
up3 = tf.keras.layers.UpSampling2D((2, 2), interpolation = 'nearest')(up2)
#up3 = ReflectionPadding2D((1, 1,))(up3)
up3 = conv_swish_gn(inp = up3, is_training = is_training, stride = (1, 1),
                    kernel_size = 3, scope = 'up3', filters = initial_flt, 
                    keep_rate = keep_rate, activation = True, use_bias = False, norm = True,
                    csse = True, dropblock = True, weight_decay = None, 
                    window_size = 104)
gru_crop = Cropping2D(6)(concat)
print(up3.shape)
print(gru_crop.shape)
up3 = tf.concat([up3, gru_crop], -1)

up3out = conv_swish_gn(inp = up3, is_training = is_training, stride = (1, 1),
                    kernel_size = 3, scope = 'out', filters = initial_flt, 
                    keep_rate  = keep_rate, activation = True,use_bias = False, norm = True,
                    csse = True, dropblock = False, weight_decay = None, padding = "VALID",
                       window_size = 104)


#print("Initializing last sigmoid bias with -2.94 constant")
init = tf.constant_initializer([-np.log(0.7/0.3)]) # For focal loss
print(f"The output is {up2.shape}, with a receptive field of {1}")

fm = Conv2D(filters = 1,
            kernel_size = (1, 1),
            padding = 'valid',
            activation = 'sigmoid',
            bias_initializer = init)(up3out)#,
print(fm)
#fm = Cropping2D(1)(fm)
"""
print(f"The output, sigmoid is {fm.shape}, with a receptive field of {1}")



up4 = conv_swish_gn(inp = up3, is_training = is_training, stride = (1, 1),
                    kernel_size = 3, scope = 'outregressor', filters = 64, 
                    keep_rate  = keep_rate, activation = True, use_bias = False, norm = True,
                    csse = True, dropblock = True, weight_decay = None, padding = "SAME")

up5 = conv_swish_gn(inp = up4, is_training = is_training, stride = (1, 1),
                    kernel_size = 3, scope = 'outregressor2', filters = 64, 
                    keep_rate  = keep_rate, activation = True, use_bias = False, norm = True,
                    csse = True, dropblock = False, weight_decay = None, padding = "VALID")

regression = Conv2D(filters = 1,
            kernel_size = (1, 1),
            padding = 'valid',
            activation = 'linear',
            #bias_initializer = init,
           )(up5)
regression = Cropping2D(1)(regression)
output = regression + fm
"""
# Out:
# GRU input shape (1, 4, 172, 172, 17), zoneout: 0.1
# (1, 4, 172, 172, 17)
# (3, 3, 49, 64)
# (3, 3, 49, 64)
# Zoneout: 0.75
# Down block output shape (1, 172, 172, 64)
# conv_median 3 Conv 2D Group Norm RELU CSSE NoBias DropBlock
# The non normalized feats are Tensor("conv_median_conv/conv_median/x/mul:0", shape=(1, 172, 172, 64), dtype=float32)
# The non normalized feats are Tensor("IdentityN:0", shape=(1, 172, 172, 64), dtype=float32)
# /var/folders/kk/09dbtcq15sb84xb9mrj4g1s00000gp/T/ipykernel_13136/3040874010.py:29: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   update_mask = tf.layers.conv2d(mask, filters=1,
# Median conv: (1, 172, 172, 64)
# conv_concat 3 Conv 2D Group Norm RELU CSSE NoBias DropBlock
# The non normalized feats are Tensor("conv_concat_conv/conv_concat/x/mul:0", shape=(1, 172, 172, 64), dtype=float32)
# The non normalized feats are Tensor("IdentityN_1:0", shape=(1, 172, 172, 64), dtype=float32)
# Concat: (1, 172, 172, 64)
# conv1 3 Conv 2D Group Norm RELU CSSE NoBias DropBlock
# The non normalized feats are Tensor("conv1_conv/conv1/ws_conv2d_2/WSConv2D:0", shape=(1, 84, 84, 128), dtype=float32)
# The non normalized feats are Tensor("IdentityN_2:0", shape=(1, 84, 84, 128), dtype=float32)
# Conv1: (1, 84, 84, 128)
# conv2 3 Conv 2D Group Norm RELU CSSE NoBias DropBlock
# The non normalized feats are Tensor("conv2_conv/conv2/ws_conv2d_3/WSConv2D:0", shape=(1, 40, 40, 256), dtype=float32)
# The non normalized feats are Tensor("IdentityN_3:0", shape=(1, 40, 40, 256), dtype=float32)
# Encoded (1, 40, 40, 256)
# up2 3 Conv 2D Group Norm RELU CSSE NoBias DropBlock
# The non normalized feats are Tensor("up2_conv/up2/x/mul:0", shape=(1, 80, 80, 128), dtype=float32)
# The non normalized feats are Tensor("IdentityN_4:0", shape=(1, 80, 80, 128), dtype=float32)
# (1, 80, 80, 128)
# up2_out 3 Conv 2D Group Norm RELU CSSE NoBias DropBlock
# The non normalized feats are Tensor("up2_out_conv/up2_out/x/mul:0", shape=(1, 80, 80, 128), dtype=float32)
# The non normalized feats are Tensor("IdentityN_5:0", shape=(1, 80, 80, 128), dtype=float32)
# up3 3 Conv 2D Group Norm RELU CSSE NoBias DropBlock
# The non normalized feats are Tensor("up3_conv/up3/x/mul:0", shape=(1, 160, 160, 64), dtype=float32)
# The non normalized feats are Tensor("IdentityN_6:0", shape=(1, 160, 160, 64), dtype=float32)
# (1, 160, 160, 64)
# (1, 160, 160, 64)
# out 3 Conv 2D Group Norm RELU CSSE NoBias NoDrop
# The non normalized feats are Tensor("out_conv/out/ws_conv2d_7/WSConv2D:0", shape=(1, 158, 158, 64), dtype=float32)
# The non normalized feats are Tensor("IdentityN_7:0", shape=(1, 158, 158, 64), dtype=float32)
# The output is (1, 80, 80, 128), with a receptive field of 1
# Tensor("conv2d_5/Sigmoid:0", shape=(1, 158, 158, 1), dtype=float32)
# '\nprint(f"The output, sigmoid is {fm.shape}, with a receptive field of {1}")\n\n\n\nup4 = conv_swish_gn(inp = up3, is_training = is_training, stride = (1, 1),\n                    kernel_size = 3, scope = \'outregressor\', filters = 64, \n                    keep_rate  = keep_rate, activation = True, use_bias = False, norm = True,\n                    csse = True, dropblock = True, weight_decay = None, padding = "SAME")\n\nup5 = conv_swish_gn(inp = up4, is_training = is_training, stride = (1, 1),\n                    kernel_size = 3, scope = \'outregressor2\', filters = 64, \n                    keep_rate  = keep_rate, activation = True, use_bias = False, norm = True,\n                    csse = True, dropblock = False, weight_decay = None, padding = "VALID")\n\nregression = Conv2D(filters = 1,\n            kernel_size = (1, 1),\n            padding = \'valid\',\n            activation = \'linear\',\n            #bias_initializer = init,\n           )(up5)\nregression = Cropping2D(1)(regression)\noutput = regression + fm\n'

# %%
from keras.losses import binary_crossentropy
import math
from scipy.ndimage import distance_transform_edt as distance

def calc_mask(seg):

    res = np.zeros_like(seg)
    posmask = seg.astype(np.bool)
    loss_importance = np.array([x for x in range(0, 197, 1)])
    loss_importance = loss_importance / 196
    loss_importance = np.expm1(loss_importance)
    loss_importance[:30] = 0.

    if posmask.any():
        negmask = ~posmask
        res = distance(negmask) * negmask - (distance(posmask) - 1) * posmask
    if np.sum(seg) == 196:
        res = np.ones_like(seg)
    if np.sum(seg) == 0:
        res = np.ones_like(seg)
    res[np.logical_and(res < 2, res > 0)] = 0.5
    res[np.logical_or(res >= 2, res <= 0)] = 1.
    return res

def calc_mask_batch(y_true):
    '''Applies calc_dist_map to each sample in an input batch
    
         Parameters:
          y_true (arr):
          
         Returns:
          loss (arr):
    '''
    y_true_numpy = y_true.numpy()
    bce_batch = np.array([calc_mask(y)
                     for y in y_true_numpy]).astype(np.float32)
    return bce_batch

def weighted_bce_loss(y_true, y_pred, weight, mask = True, smooth = 0.03):
    '''Calculates the weighted binary cross entropy loss between y_true and
       y_pred with optional masking and smoothing for regularization
       
       For smoothing, we want to weight false positives as less important than
       false negatives, so we smooth false negatives 2x as much. 
    
         Parameters:
          y_true (arr):
          y_pred (arr):
          weight (float):
          mask (arr):
          smooth (float):

         Returns:
          loss (float):
    '''
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    y_true = K.clip(y_true, smooth, 1. - smooth)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    loss = tf.nn.weighted_cross_entropy_with_logits(
        y_true,
        logit_y_pred,
        weight,
    )

    return loss

def calc_dist_map(seg):
    #Utility function for calc_dist_map_batch that calculates the loss
    #   importance per pixel based on the surface distance function
    
     #    Parameters:
    #      seg (arr):
     #     
    #     Returns:
    #      res (arr):
    #
    res = np.zeros_like(seg)
    posmask = seg.astype(np.bool)

    mults = np.ones_like(seg)
    ones = np.ones_like(seg)
    for x in range(1, res.shape[0] -1 ):
        for y in range(1, res.shape[0] - 1):
            if seg[x, y] == 1:
                l = seg[x - 1, y]
                r = seg[x + 1, y]
                u = seg[x, y + 1]
                d = seg[x, y - 1]
                lu = seg[x - 1, y + 1]
                ru = seg[x + 1, y + 1]
                rd = seg[x + 1, y - 1]
                ld = seg[x -1, y - 1]
                
                sums = (l + r + u + d)
                sums2 = (l + r + u + d + lu + ru +rd + ld)
                if sums >= 2:
                    mults[x, y] = 2
                if sums2 <= 1:
                    ones[x - 1, y] = 0.5
                    ones[x + 1, y] = 0.5
                    ones[x, y + 1] = 0.5
                    ones[x, y - 1] = 0.5
                    ones[x - 1, y + 1] = 0.5
                    ones[x + 1, y + 1] = 0.5
                    ones[x + 1, y - 1] = 0.5
                    ones[x -1, y - 1] = 0.5

    if posmask.any():
        
        negmask = ~posmask
        res = distance(negmask) * negmask - (distance(posmask) - 1) * posmask
        # When % = 1, 0 -> 1.75
        # When % = 100, 0 -> 0
        res = np.round(res, 0)
        res[np.where(np.isclose(res, -.41421356, rtol = 1e-2))] = -1
        res[np.where(res == -1)] = -1 * mults[np.where(res == -1)]
        res[np.where(res == 0)] = -1  * mults[np.where(res == 0)]
        # When % = 1, 1 -> 0
        # When % = 100, 1 -> 1.75
        res[np.where(res == 1)] = 1 * ones[np.where(res == 1)]
        res[np.where(res == 1)] *= 0.67
        #res[np.where(np.isclose(res, 1.41421356, rtol = 1e-2))] = loss_importance[sums]
        
    res[np.where(res < -3)] = -3
    res[np.where(res > 3)] = 3
    if np.sum(seg) == 196:
        res = np.ones_like(seg)
        res *= -1
    if np.sum(seg) == 0:
        res = np.ones_like(seg)
    return res


def calc_dist_map_batch(y_true):
    '''Applies calc_dist_map to each sample in an input batch
    
         Parameters:
          y_true (arr):
          
         Returns:
          loss (arr):
    '''
    y_true_numpy = y_true.numpy()
    return np.array([calc_dist_map(y)
                     for y in y_true_numpy]).astype(np.float32)

def surface_loss(y_true, y_pred):
    '''Calculates the mean surface loss for the input batch
       by multiplying the distance map by y_pred
    
         Parameters:
          y_true (arr):
          y_pred (arr):
          
         Returns:
          loss (arr):
        
         References:
          https://arxiv.org/abs/1812.07032
    '''
    y_true_dist_map = tf.py_function(func=calc_dist_map_batch,
                                     inp=[y_true],
                                     Tout=tf.float32)
    y_true_dist_map = tf.stack(y_true_dist_map, axis = 0)
    multipled = y_pred * y_true_dist_map
    loss = tf.reduce_mean(multipled, axis = (1, 2, 3))
    return loss

def tf_percentile(x, p):
    with tf.name_scope('percentile'):
        y = tf.transpose(x)  # take percentile over batch dimension
        sorted_y = tf.sort(y)
        frac_idx = tf.cast(p, tf.float64) / 100. * (tf.cast(tf.shape(y)[-1], tf.float64) - 1.)
        return 0.5 * (  # using midpoint rule
            tf.gather(sorted_y, tf.cast(tf.math.ceil(frac_idx), tf.int32), axis=-1)
            + tf.gather(sorted_y, tf.cast(tf.math.floor(frac_idx), tf.int32), axis=-1))

def lovasz_surf(y_true, y_pred, alpha, weight, beta):
    
    #lv = lovasz_softmax(probas = y_pred,
    #                    labels = tf.reshape(y_true, (-1, 14, 14)), 
    #                    classes=[1],
    #                    per_image=False) 
    
    bce = weighted_bce_loss(y_true = y_true, 
                             y_pred = y_pred, 
                             weight = weight,
                             smooth = 0.05)


    bce = tf.reduce_mean(bce, axis = (1, 2, 3))
    surface = surface_loss(tf.cast(tf.math.greater(y_true, 0.10), tf.float32), y_pred)
    surface = tf.reshape(surface, tf.shape(bce))
    print(surface.shape)

    bce = (1 - alpha) * bce
    surface_portion = alpha * surface
    
    #result = bce + lovasz
    result = bce + surface_portion
    upper_bound = tf_percentile(result, 90)
    result = tf.clip_by_value(result, tf.reduce_min(result), upper_bound)
    result = tf.reduce_mean(result)
    return result

# %%
def weighted_bce_loss(y_true, y_pred, weight, mask = True, smooth = 0.05):
    '''Calculates the weighted binary cross entropy loss between y_true and
       y_pred with optional masking and smoothing for regularization
       
       For smoothing, we want to weight false positives as less important than
       false negatives, so we smooth false negatives 2x as much. 
    
         Parameters:
          y_true (arr):
          y_pred (arr):
          weight (float):
          mask (arr):
          smooth (float):

         Returns:
          loss (float):
    '''
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    y_true = K.clip(y_true, smooth / 5, 1. - smooth)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    
    paddings = paddings = tf.constant([[0, 0], [1, 1], [1, 1], [0, 0]])
    logit_y_pred_positive = tf.pad(
        logit_y_pred, paddings, mode='CONSTANT', name=None, constant_values=0,
    )
    logit_y_pred_maximum = MaxPool2D(pool_size=(3, 3), strides=(1, 1), padding='valid')(logit_y_pred_positive)
    loss_negative = tf.nn.weighted_cross_entropy_with_logits(
        y_true,
        logit_y_pred,
        weight,
    )
    
    loss_positive = loss_negative = tf.nn.weighted_cross_entropy_with_logits(
        y_true,
        logit_y_pred_maximum,
        weight,
    )
    
    where_positive = tf.cast(tf.math.greater(y_true, 0.5), tf.float32)
    where_negative = 1 - where_positive
    loss_positive = loss_positive * where_positive
    loss_negative = loss_negative * where_negative
                                                     

    return (loss_positive + loss_negative)

# %%
# %run ../../src/layers/adabound.py
def grad_norm(gradients):
        norm = tf.norm(
            tf.stack([
                tf.norm(grad) for grad in gradients if grad is not None
            ])
        )
        return norm
    

optimizer = AdaBoundOptimizer(1e-3, 0.1)
train_loss = lovasz_surf(tf.reshape(labels, (-1, INPUT_SIZE - 14, SIZE_X - 14, 1)), 
                         fm, weight = loss_weight, 
                         alpha = alpha, beta = beta_)
#train_loss2 = lovasz_surf(tf.reshape(labels, (-1, INPUT_SIZE - 14, SIZE_X - 14, 1)), 
#                         regression, weight = loss_weight, 
#                         alpha = alpha, beta = beta_)
train_loss = train_loss# + train_loss2
#l2_loss = tf.losses.get_regularization_loss()
#if len(tf.losses.get_regularization_losses()) > 0:
#    print("Adding L2 loss")
#    train_loss = train_loss + l2_loss

test_loss = lovasz_surf(tf.reshape(labels, (-1, INPUT_SIZE - 14, SIZE_X - 14, 1)),
                        fm, weight = loss_weight, 
                        alpha = alpha, beta = beta_)
update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)

with tf.control_dependencies(update_ops):
    train_op = optimizer.minimize(train_loss)   
"""
trainable_params = tf.trainable_variables()
gradients = optimizer.compute_gradients(loss=train_loss, var_list=None)
gradient_norm = grad_norm(gradients)
scale = 0.05 / (gradient_norm + 1e-12)
e_ws = []
for (grad, param) in gradients:
    e_w = grad * scale
    param.assign_add(e_w)
    e_ws.append(e_w)

sam_gradients = optimizer.compute_gradients(loss=train_loss, var_list=None)
for (param, e_w) in zip(trainable_params, e_ws):
    param.assign_sub(e_w)
train_step = optimizer.apply_gradients(sam_gradients)
"""

init_op = tf.global_variables_initializer()
sess.run(init_op)
saver = tf.train.Saver(max_to_keep = 150)
# Out:
# (?,)
# (?,)
# 2024-01-09 13:47:32.691566: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2024-01-09 13:47:32.722495: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2024-01-09 13:47:32.723393: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
def get_tensors_in_checkpoint_file(file_name,all_tensors=True,tensor_name=None):
    varlist=[]
    var_value =[]
    reader = tf.compat.v1.train.NewCheckpointReader(file_name)
    if all_tensors:
        var_to_shape_map = reader.get_variable_to_shape_map()
        for key in sorted(var_to_shape_map):
            varlist.append(key)
            var_value.append(reader.get_tensor(key))
    else:
        varlist.append(tensor_name)
        var_value.append(reader.get_tensor(tensor_name))
    return (varlist, var_value)

def build_tensors_in_checkpoint_file(loaded_tensors):
    full_var_list = list()
    # Loop all loaded tensors
    for i, tensor_name in enumerate(loaded_tensors[0]):
        # Extract tensor
        try:
            tensor_aux = tf.get_default_graph().get_tensor_by_name(tensor_name+":0")
            full_var_list.append(tensor_aux)
        except:
            print('Not found: '+tensor_name)
        
    return full_var_list

checkpoint_dir = "../../models/tml-july-18-2-150-july28/"
all_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
all_vars = [x for x in all_vars if 'conv3d' not in x.name]
all_vars = [x for x in all_vars if 'conv2d/' not in x.name]
all_vars = [x for x in all_vars if 'conv2d_1' not in x.name]
all_vars = [x for x in all_vars if 'conv2d_2' not in x.name]
all_vars = [x for x in all_vars if 'conv2d_3' not in x.name]
all_vars = [x for x in all_vars if 'conv2d_4' not in x.name]
all_vars = [x for x in all_vars if 'conv2d_5' not in x.name]
    
saver = tf.train.Saver(max_to_keep = 150, var_list = all_vars)
#restored_vars[0]
#tensors_to_load = build_tensors_in_checkpoint_file(restored_vars)
#saver.restore(sess, CHECKPOINT_NAME)

# %%
all_vars
# Out:
# [<tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel:0' shape=(3, 3, 49, 64) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel:0' shape=(3, 3, 49, 32) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1:0' shape=(1, 1, 32, 1) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/gates/kernel:0' shape=(3, 3, 49, 64) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/beta_gates_r:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/beta_gates_u:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel:0' shape=(3, 3, 49, 32) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel_1:0' shape=(1, 1, 32, 1) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'conv_median_norm/gamma_conv_median:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_median_norm/beta_conv_median:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'csse_conv_median_conv/kernel:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_conv_median_conv/bias:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'conv_concat_norm/gamma_conv_concat:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_concat_norm/beta_conv_concat:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'csse_conv_concat_conv/kernel:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_conv_concat_conv/bias:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'conv1_norm/gamma_conv1:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'conv1_norm/beta_conv1:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'csse_conv1_conv/kernel:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_conv1_conv/bias:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'conv2_norm/gamma_conv2:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'conv2_norm/beta_conv2:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'csse_conv2_conv/kernel:0' shape=(1, 1, 256, 1) dtype=float32>,
#  <tf.Variable 'csse_conv2_conv/bias:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'up2_norm/gamma_up2:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_norm/beta_up2:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'csse_up2_conv/kernel:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_up2_conv/bias:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'up2_out_norm/gamma_up2_out:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_out_norm/beta_up2_out:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'csse_up2_out_conv/kernel:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_up2_out_conv/bias:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'up3_conv/up3/x/ws_conv2d_6/kernel:0' shape=(3, 3, 128, 64) dtype=float32>,
#  <tf.Variable 'up3_norm/gamma_up3:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'up3_norm/beta_up3:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'csse_up3_conv/kernel:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_up3_conv/bias:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'out_conv/out/ws_conv2d_7/kernel:0' shape=(3, 3, 128, 64) dtype=float32>,
#  <tf.Variable 'out_norm/gamma_out:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'out_norm/beta_out:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'csse_out_conv/kernel:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_out_conv/bias:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'beta1_power:0' shape=() dtype=float32>,
#  <tf.Variable 'beta2_power:0' shape=() dtype=float32>,
#  <tf.Variable 'gamma_multi:0' shape=() dtype=float32>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel/AdaBound:0' shape=(3, 3, 49, 64) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel/AdaBound_1:0' shape=(3, 3, 49, 64) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel/AdaBound_2:0' shape=(3, 3, 49, 64) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel/AdaBound:0' shape=(3, 3, 49, 32) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel/AdaBound_1:0' shape=(3, 3, 49, 32) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel/AdaBound_2:0' shape=(3, 3, 49, 32) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1/AdaBound:0' shape=(1, 1, 32, 1) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1/AdaBound_1:0' shape=(1, 1, 32, 1) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1/AdaBound_2:0' shape=(1, 1, 32, 1) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/gates/kernel/AdaBound:0' shape=(3, 3, 49, 64) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/gates/kernel/AdaBound_1:0' shape=(3, 3, 49, 64) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/gates/kernel/AdaBound_2:0' shape=(3, 3, 49, 64) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/beta_gates_r/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/beta_gates_r/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/beta_gates_r/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/beta_gates_u/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/beta_gates_u/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/beta_gates_u/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel/AdaBound:0' shape=(3, 3, 49, 32) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel/AdaBound_1:0' shape=(3, 3, 49, 32) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel/AdaBound_2:0' shape=(3, 3, 49, 32) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel_1/AdaBound:0' shape=(1, 1, 32, 1) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel_1/AdaBound_1:0' shape=(1, 1, 32, 1) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel_1/AdaBound_2:0' shape=(1, 1, 32, 1) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y/AdaBound:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y/AdaBound_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y/AdaBound_2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'conv_median_norm/gamma_conv_median/AdaBound:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_median_norm/gamma_conv_median/AdaBound_1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_median_norm/gamma_conv_median/AdaBound_2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_median_norm/beta_conv_median/AdaBound:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_median_norm/beta_conv_median/AdaBound_1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_median_norm/beta_conv_median/AdaBound_2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'csse_conv_median_conv/kernel/AdaBound:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_conv_median_conv/kernel/AdaBound_1:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_conv_median_conv/kernel/AdaBound_2:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_conv_median_conv/bias/AdaBound:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_conv_median_conv/bias/AdaBound_1:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_conv_median_conv/bias/AdaBound_2:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'conv_concat_norm/gamma_conv_concat/AdaBound:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_concat_norm/gamma_conv_concat/AdaBound_1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_concat_norm/gamma_conv_concat/AdaBound_2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_concat_norm/beta_conv_concat/AdaBound:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_concat_norm/beta_conv_concat/AdaBound_1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'conv_concat_norm/beta_conv_concat/AdaBound_2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'csse_conv_concat_conv/kernel/AdaBound:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_conv_concat_conv/kernel/AdaBound_1:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_conv_concat_conv/kernel/AdaBound_2:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_conv_concat_conv/bias/AdaBound:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_conv_concat_conv/bias/AdaBound_1:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_conv_concat_conv/bias/AdaBound_2:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'conv1_norm/gamma_conv1/AdaBound:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'conv1_norm/gamma_conv1/AdaBound_1:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'conv1_norm/gamma_conv1/AdaBound_2:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'conv1_norm/beta_conv1/AdaBound:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'conv1_norm/beta_conv1/AdaBound_1:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'conv1_norm/beta_conv1/AdaBound_2:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'csse_conv1_conv/kernel/AdaBound:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_conv1_conv/kernel/AdaBound_1:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_conv1_conv/kernel/AdaBound_2:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_conv1_conv/bias/AdaBound:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_conv1_conv/bias/AdaBound_1:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_conv1_conv/bias/AdaBound_2:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'conv2_norm/gamma_conv2/AdaBound:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'conv2_norm/gamma_conv2/AdaBound_1:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'conv2_norm/gamma_conv2/AdaBound_2:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'conv2_norm/beta_conv2/AdaBound:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'conv2_norm/beta_conv2/AdaBound_1:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'conv2_norm/beta_conv2/AdaBound_2:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'csse_conv2_conv/kernel/AdaBound:0' shape=(1, 1, 256, 1) dtype=float32>,
#  <tf.Variable 'csse_conv2_conv/kernel/AdaBound_1:0' shape=(1, 1, 256, 1) dtype=float32>,
#  <tf.Variable 'csse_conv2_conv/kernel/AdaBound_2:0' shape=(1, 1, 256, 1) dtype=float32>,
#  <tf.Variable 'csse_conv2_conv/bias/AdaBound:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_conv2_conv/bias/AdaBound_1:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_conv2_conv/bias/AdaBound_2:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'up2_norm/gamma_up2/AdaBound:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_norm/gamma_up2/AdaBound_1:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_norm/gamma_up2/AdaBound_2:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_norm/beta_up2/AdaBound:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_norm/beta_up2/AdaBound_1:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_norm/beta_up2/AdaBound_2:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'csse_up2_conv/kernel/AdaBound:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_up2_conv/kernel/AdaBound_1:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_up2_conv/kernel/AdaBound_2:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_up2_conv/bias/AdaBound:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_up2_conv/bias/AdaBound_1:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_up2_conv/bias/AdaBound_2:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'up2_out_norm/gamma_up2_out/AdaBound:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_out_norm/gamma_up2_out/AdaBound_1:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_out_norm/gamma_up2_out/AdaBound_2:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_out_norm/beta_up2_out/AdaBound:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_out_norm/beta_up2_out/AdaBound_1:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'up2_out_norm/beta_up2_out/AdaBound_2:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'csse_up2_out_conv/kernel/AdaBound:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_up2_out_conv/kernel/AdaBound_1:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_up2_out_conv/kernel/AdaBound_2:0' shape=(1, 1, 128, 1) dtype=float32>,
#  <tf.Variable 'csse_up2_out_conv/bias/AdaBound:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_up2_out_conv/bias/AdaBound_1:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_up2_out_conv/bias/AdaBound_2:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'up3_conv/up3/x/ws_conv2d_6/kernel/AdaBound:0' shape=(3, 3, 128, 64) dtype=float32>,
#  <tf.Variable 'up3_conv/up3/x/ws_conv2d_6/kernel/AdaBound_1:0' shape=(3, 3, 128, 64) dtype=float32>,
#  <tf.Variable 'up3_conv/up3/x/ws_conv2d_6/kernel/AdaBound_2:0' shape=(3, 3, 128, 64) dtype=float32>,
#  <tf.Variable 'up3_norm/gamma_up3/AdaBound:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'up3_norm/gamma_up3/AdaBound_1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'up3_norm/gamma_up3/AdaBound_2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'up3_norm/beta_up3/AdaBound:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'up3_norm/beta_up3/AdaBound_1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'up3_norm/beta_up3/AdaBound_2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'csse_up3_conv/kernel/AdaBound:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_up3_conv/kernel/AdaBound_1:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_up3_conv/kernel/AdaBound_2:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_up3_conv/bias/AdaBound:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_up3_conv/bias/AdaBound_1:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_up3_conv/bias/AdaBound_2:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'out_conv/out/ws_conv2d_7/kernel/AdaBound:0' shape=(3, 3, 128, 64) dtype=float32>,
#  <tf.Variable 'out_conv/out/ws_conv2d_7/kernel/AdaBound_1:0' shape=(3, 3, 128, 64) dtype=float32>,
#  <tf.Variable 'out_conv/out/ws_conv2d_7/kernel/AdaBound_2:0' shape=(3, 3, 128, 64) dtype=float32>,
#  <tf.Variable 'out_norm/gamma_out/AdaBound:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'out_norm/gamma_out/AdaBound_1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'out_norm/gamma_out/AdaBound_2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'out_norm/beta_out/AdaBound:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'out_norm/beta_out/AdaBound_1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'out_norm/beta_out/AdaBound_2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'csse_out_conv/kernel/AdaBound:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_out_conv/kernel/AdaBound_1:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_out_conv/kernel/AdaBound_2:0' shape=(1, 1, 64, 1) dtype=float32>,
#  <tf.Variable 'csse_out_conv/bias/AdaBound:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_out_conv/bias/AdaBound_1:0' shape=(1,) dtype=float32>,
#  <tf.Variable 'csse_out_conv/bias/AdaBound_2:0' shape=(1,) dtype=float32>]

# %%
i = 0

# %%
fm2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 fm2
#
# NameError: name 'fm2' is not defined

# %%
current_items = []
varss_dict = {}
for var_current in tf.global_variables():
    print(var_current.op)
    current_items.append(var_current.op.name) # this gets only name
    #vars_dict[var_ckpt[0]] = tf.get_variable(var_current.op.name, var_current.shape)
current_items= sorted(current_items)
current_items
vars_dict = {}
#for var_current in tf.global_variables():
##    print(var_current.op.name) # this gets only name
ckpt_items = []
for var_ckpt in tf.train.list_variables("../../models/tf2/"):
    if 'BackupVariables' not in var_ckpt[0]:
        if 'StochasticWeightAveraging' not in var_ckpt[0]:
            if 'global_step' not in var_ckpt[0]:
                if 'is_training' not in var_ckpt[0]:
                    if 'n_models' not in var_ckpt[0]:
                        ckpt_items.append(var_ckpt[0])
                        
                        ckptdict = {}
#for y, x in zip(ckpt_items[26:28], current_items[26:28]):
#    ckptdict[y] = tf.get_default_graph().get_tensor_by_name(x + ":0")
# Out:
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/bw/conv_gru_cell/gates/kernel"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/bw/conv_gru_cell/gates/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/beta_gates_r"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_r_norm/beta_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/beta_gates_u"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/gates/gates_u_norm/beta_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/bw/conv_gru_cell/candidate/kernel_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/bw/bw/while/bw/conv_gru_cell/candidate/candidate_y_norm/beta_candidate_y"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "conv_median_conv/conv_median/mask/conv2d/kernel"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv_median_conv/conv_median/mask/conv2d/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "conv_median_conv/conv_median/x/ws_conv2d/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv_median_conv/conv_median/x/ws_conv2d/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 17
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv_median_conv/conv_median/x/ws_conv2d/kernel"
#   }
# }
#
# name: "conv_median_norm/gamma_conv_median"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv_median_norm/gamma_conv_median"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "conv_median_norm/beta_conv_median"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv_median_norm/beta_conv_median"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_conv_median_conv/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_conv_median_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_conv_median_conv/kernel"
#   }
# }
#
# name: "csse_conv_median_conv/bias"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_conv_median_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_conv_median_conv/bias"
#   }
# }
#
# name: "conv_concat_conv/conv_concat/mask/conv2d/kernel"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv_concat_conv/conv_concat/mask/conv2d/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "conv_concat_conv/conv_concat/x/ws_conv2d_1/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv_concat_conv/conv_concat/x/ws_conv2d_1/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv_concat_conv/conv_concat/x/ws_conv2d_1/kernel"
#   }
# }
#
# name: "conv_concat_norm/gamma_conv_concat"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv_concat_norm/gamma_conv_concat"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "conv_concat_norm/beta_conv_concat"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv_concat_norm/beta_conv_concat"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_conv_concat_conv/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_conv_concat_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_conv_concat_conv/kernel"
#   }
# }
#
# name: "csse_conv_concat_conv/bias"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_conv_concat_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_conv_concat_conv/bias"
#   }
# }
#
# name: "conv1_conv/conv1/ws_conv2d_2/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv1_conv/conv1/ws_conv2d_2/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv1_conv/conv1/ws_conv2d_2/kernel"
#   }
# }
#
# name: "conv1_norm/gamma_conv1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv1_norm/gamma_conv1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "conv1_norm/beta_conv1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv1_norm/beta_conv1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_conv1_conv/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_conv1_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_conv1_conv/kernel"
#   }
# }
#
# name: "csse_conv1_conv/bias"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_conv1_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_conv1_conv/bias"
#   }
# }
#
# name: "conv2_conv/conv2/ws_conv2d_3/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2_conv/conv2/ws_conv2d_3/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv2_conv/conv2/ws_conv2d_3/kernel"
#   }
# }
#
# name: "conv2_norm/gamma_conv2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2_norm/gamma_conv2"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "conv2_norm/beta_conv2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2_norm/beta_conv2"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 256
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_conv2_conv/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_conv2_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 256
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_conv2_conv/kernel"
#   }
# }
#
# name: "csse_conv2_conv/bias"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_conv2_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_conv2_conv/bias"
#   }
# }
#
# name: "up2_conv/up2/mask/conv2d/kernel"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up2_conv/up2/mask/conv2d/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up2_conv/up2/x/ws_conv2d_4/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up2_conv/up2/x/ws_conv2d_4/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 256
#       }
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "up2_conv/up2/x/ws_conv2d_4/kernel"
#   }
# }
#
# name: "up2_norm/gamma_up2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up2_norm/gamma_up2"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up2_norm/beta_up2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up2_norm/beta_up2"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_up2_conv/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up2_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up2_conv/kernel"
#   }
# }
#
# name: "csse_up2_conv/bias"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up2_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up2_conv/bias"
#   }
# }
#
# name: "up2_out_conv/up2_out/mask/conv2d/kernel"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up2_out_conv/up2_out/mask/conv2d/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up2_out_conv/up2_out/x/ws_conv2d_5/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up2_out_conv/up2_out/x/ws_conv2d_5/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 256
#       }
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "up2_out_conv/up2_out/x/ws_conv2d_5/kernel"
#   }
# }
#
# name: "up2_out_norm/gamma_up2_out"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up2_out_norm/gamma_up2_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up2_out_norm/beta_up2_out"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up2_out_norm/beta_up2_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 128
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_up2_out_conv/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up2_out_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up2_out_conv/kernel"
#   }
# }
#
# name: "csse_up2_out_conv/bias"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up2_out_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up2_out_conv/bias"
#   }
# }
#
# name: "up3_conv/up3/mask/conv2d/kernel"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up3_conv/up3/mask/conv2d/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up3_conv/up3/x/ws_conv2d_6/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up3_conv/up3/x/ws_conv2d_6/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "up3_conv/up3/x/ws_conv2d_6/kernel"
#   }
# }
#
# name: "up3_norm/gamma_up3"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up3_norm/gamma_up3"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up3_norm/beta_up3"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up3_norm/beta_up3"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_up3_conv/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up3_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up3_conv/kernel"
#   }
# }
#
# name: "csse_up3_conv/bias"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up3_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up3_conv/bias"
#   }
# }
#
# name: "out_conv/out/ws_conv2d_7/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_conv/out/ws_conv2d_7/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "out_conv/out/ws_conv2d_7/kernel"
#   }
# }
#
# name: "out_norm/gamma_out"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_norm/gamma_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_norm/beta_out"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_norm/beta_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_out_conv/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_out_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_out_conv/kernel"
#   }
# }
#
# name: "csse_out_conv/bias"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_out_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_out_conv/bias"
#   }
# }
#
# name: "conv2d_5/kernel"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2d_5/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv2d_5/kernel"
#   }
# }
#
# name: "conv2d_5/bias"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2d_5/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv2d_5/bias"
#   }
# }
#
# name: "beta1_power"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv1_conv/conv1/ws_conv2d_2/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "beta1_power"
#   }
# }
#
# name: "beta2_power"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv1_conv/conv1/ws_conv2d_2/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "beta2_power"
#   }
# }
#
# name: "gamma_multi"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv1_conv/conv1/ws_conv2d_2/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "gamma_multi"
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/gates/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/gamma_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_r_norm/beta_gates_r"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/gamma_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/gates/gates_u_norm/beta_gates_u"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 49
#       }
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/conv_gru_cell/candidate/kernel_1"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 32
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 32
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@down_16/bidirectional_rnn/fw/fw/while/fw/conv_gru_cell/candidate/candidate_y_norm/gamma_candidate_y"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
# ...
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up3_norm/gamma_up3/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up3_norm/gamma_up3"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up3_norm/beta_up3/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up3_norm/beta_up3"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up3_norm/beta_up3/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up3_norm/beta_up3"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "up3_norm/beta_up3/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@up3_norm/beta_up3"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_up3_conv/kernel/AdaBound"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up3_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up3_conv/kernel/AdaBound"
#   }
# }
#
# name: "csse_up3_conv/kernel/AdaBound_1"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up3_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up3_conv/kernel/AdaBound_1"
#   }
# }
#
# name: "csse_up3_conv/kernel/AdaBound_2"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up3_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up3_conv/kernel/AdaBound_2"
#   }
# }
#
# name: "csse_up3_conv/bias/AdaBound"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up3_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up3_conv/bias/AdaBound"
#   }
# }
#
# name: "csse_up3_conv/bias/AdaBound_1"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up3_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up3_conv/bias/AdaBound_1"
#   }
# }
#
# name: "csse_up3_conv/bias/AdaBound_2"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_up3_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_up3_conv/bias/AdaBound_2"
#   }
# }
#
# name: "out_conv/out/ws_conv2d_7/kernel/AdaBound"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_conv/out/ws_conv2d_7/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "out_conv/out/ws_conv2d_7/kernel/AdaBound"
#   }
# }
#
# name: "out_conv/out/ws_conv2d_7/kernel/AdaBound_1"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_conv/out/ws_conv2d_7/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "out_conv/out/ws_conv2d_7/kernel/AdaBound_1"
#   }
# }
#
# name: "out_conv/out/ws_conv2d_7/kernel/AdaBound_2"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_conv/out/ws_conv2d_7/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 3
#       }
#       dim {
#         size: 3
#       }
#       dim {
#         size: 128
#       }
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "out_conv/out/ws_conv2d_7/kernel/AdaBound_2"
#   }
# }
#
# name: "out_norm/gamma_out/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_norm/gamma_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_norm/gamma_out/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_norm/gamma_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_norm/gamma_out/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_norm/gamma_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_norm/beta_out/AdaBound"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_norm/beta_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_norm/beta_out/AdaBound_1"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_norm/beta_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "out_norm/beta_out/AdaBound_2"
# op: "VariableV2"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@out_norm/beta_out"
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 64
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: ""
#   }
# }
#
# name: "csse_out_conv/kernel/AdaBound"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_out_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_out_conv/kernel/AdaBound"
#   }
# }
#
# name: "csse_out_conv/kernel/AdaBound_1"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_out_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_out_conv/kernel/AdaBound_1"
#   }
# }
#
# name: "csse_out_conv/kernel/AdaBound_2"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_out_conv/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_out_conv/kernel/AdaBound_2"
#   }
# }
#
# name: "csse_out_conv/bias/AdaBound"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_out_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_out_conv/bias/AdaBound"
#   }
# }
#
# name: "csse_out_conv/bias/AdaBound_1"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_out_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_out_conv/bias/AdaBound_1"
#   }
# }
#
# name: "csse_out_conv/bias/AdaBound_2"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@csse_out_conv/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "csse_out_conv/bias/AdaBound_2"
#   }
# }
#
# name: "conv2d_5/kernel/AdaBound"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2d_5/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv2d_5/kernel/AdaBound"
#   }
# }
#
# name: "conv2d_5/kernel/AdaBound_1"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2d_5/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv2d_5/kernel/AdaBound_1"
#   }
# }
#
# name: "conv2d_5/kernel/AdaBound_2"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2d_5/kernel"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 1
#       }
#       dim {
#         size: 64
#       }
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv2d_5/kernel/AdaBound_2"
#   }
# }
#
# name: "conv2d_5/bias/AdaBound"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2d_5/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv2d_5/bias/AdaBound"
#   }
# }
#
# name: "conv2d_5/bias/AdaBound_1"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2d_5/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv2d_5/bias/AdaBound_1"
#   }
# }
#
# name: "conv2d_5/bias/AdaBound_2"
# op: "VarHandleOp"
# attr {
#   key: "_class"
#   value {
#     list {
#       s: "loc:@conv2d_5/bias"
#     }
#   }
# }
# attr {
#   key: "allowed_devices"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "container"
#   value {
#     s: ""
#   }
# }
# attr {
#   key: "dtype"
#   value {
#     type: DT_FLOAT
#   }
# }
# attr {
#   key: "shape"
#   value {
#     shape {
#       dim {
#         size: 1
#       }
#     }
#   }
# }
# attr {
#   key: "shared_name"
#   value {
#     s: "conv2d_5/bias/AdaBound_2"
#   }
# }

# %%
path = '../../models/tf2/'#2023-adabound6-reg2-retrain-master/'#fs[i]# "../../models/ft/"#adabound6-average/"#fs[i]#"../../models/aug16/"#fs[i]

saver.restore(sess, tf.train.latest_checkpoint(path))

#saver.save(sess, "../../models/224-tml-testing/model")
output_node_names = ['conv2d_5/Sigmoid']    # Output nodes
#print(i + 1, "/", len(fs))
frozen_graph_def = tf.graph_util.convert_variables_to_constants(
    sess,
    sess.graph_def,
    output_node_names)
#retrain-combined-ca-220-684/
# Save the rozen graph 
with open('../../models/tf2-172/predict_graph.pb', 'wb') as f:
    f.write(frozen_graph_def.SerializeToString())
i += 1
# Out:
# 2024-01-09 13:47:40.068697: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
